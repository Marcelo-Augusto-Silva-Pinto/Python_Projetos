# %%
import pandas as pd

df_produto = pd.read_excel(r"C:\Users\marce\OneDrive\Arquivos Antigos\Área de Trabalho\Kaggle\Projeto_Todos_Graficos\Base_dados_grafico1e2.xlsx", 'PRODUTO')
df_venda  = pd.read_excel(r"C:\Users\marce\OneDrive\Arquivos Antigos\Área de Trabalho\Kaggle\Projeto_Todos_Graficos\Base_dados_grafico1e2.xlsx", 'VENDA')

df_venda = df_venda.merge(
                    df_produto[['IDPRODUTO', 'PRECO_CUSTO', 'PRECO_VENDA' ]],
                    on='IDPRODUTO',
                    how='left'      
)

display(df_produto)
display(df_venda)

df_venda.to_excel(r"C:\Users\marce\OneDrive\Arquivos Antigos\Área de Trabalho\Kaggle\Projeto_Todos_Graficos\vendas.xlsx")
# Out:
#     IDPRODUTO                 PRODUTO           CATEGORIA UNIDADE  \
# 0           1                   Arroz           Mercearia   fardo
# 1           2                  Feijão           Mercearia   fardo
# 2           3                  Açúcar           Mercearia   fardo
# 3           4            Óleo de soja           Mercearia   caixa
# 4           5                Macarrão           Mercearia   fardo
# 5           6        Farinha de trigo           Mercearia   fardo
# 6           7                     Sal           Mercearia   fardo
# 7           8         Molho de tomate           Mercearia   caixa
# 8           9      Achocolatado em pó           Mercearia   caixa
# 9          10     Biscoitos recheados           Mercearia   caixa
# 10         11        Leite longa vida  Laticínios e Frios   caixa
# 11         12               Margarina  Laticínios e Frios   caixa
# 12         13                Manteiga  Laticínios e Frios   caixa
# ...
